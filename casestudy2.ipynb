# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a227-cloud/python-record/blob/main/casestudy2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Q2="""1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s marks"""
print(Q2)
input_str = input("Enter a string: ")
if input_str == input_str[::-1]:
  print("Palindrome")
else:
  print("Not Palindrome")
for ch in set(input_str):
  count = input_str.count(ch)
  print(f"'{ch}' appears {count} times")
# Out:
# 1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s marks
# Enter a string: monish
# Not Palindrome
# 's' appears 1 times
# 'o' appears 1 times
# 'i' appears 1 times
# 'h' appears 1 times
# 'n' appears 1 times
# 'm' appears 1 times
