# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a227-cloud/python-record/blob/main/casestudy3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Q3 = """1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s mark
"""
print(Q3)
number = input("Enter a number: ")
if number == number[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
for i in range(10):
    count = number.count(str(i))
    if count > 0:
        print(f"{i} appears {count} times")
# Out:
# 1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s mark
#
# Enter a number: 21
# Not Palindrome
# 1 appears 1 times
# 2 appears 1 times
